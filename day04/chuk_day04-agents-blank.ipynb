# %% [markdown]
# # IMPORTANT
#
# Run the following to install smolagents

# %%
# Imports
import os

from smolagents import CodeAgent, OpenAIServerModel
from dotenv import load_dotenv

# %%
# TODO: Import the tools notebook
# %run /content/chuk_day04-tools-blank.ipynb

# %%
# TODO: Get the Huggingface token
# IMPORTANT: Before you run this cell, create a file called .env in day04 directory
# and add the following line into the file
# OPENAI_API_KEY=OpenAI_API_key

# %%
# TODO: Load an agent
result = load_dotenv('/content/dot_env')
print(f'loaded = {result}')
# Out:
# loaded = True

# %%
API_KEY = os.getenv('OPENAI_API_KEY')
#print(f'API_KEY = {API_KEY}')

# %%
model = 'gpt-4.1-mini'
# Load the OpenAI model
agent_model = OpenAIServerModel(model_id=model, api_key=API_KEY)

# Create code agent with the model
agent = CodeAgent(model=agent_model, add_base_tools=True, tools=[])

# %%
# TODO: List of tools
for t in agent.tools.keys():
  print(t)
# Out:
# web_search
# visit_webpage
# final_answer

# %%
# TODO Run a simple query
question = "Will I get to read George RR Martin's The Winds of Winter in my lifetime?"
result = agent.run(question)
print(result)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Will I get to read George RR Martin's The Winds of Winter in my lifetime?                                       │
# │                                                                                                                 │
# ╰─ OpenAIServerModel - gpt-4.1-mini ──────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="George RR Martin The Winds of Winter release date 2024")
#   print(search_results)
# ...

# %%
# TODO: Create an agent with our own tools
tools = [ get_latlng, get_temperature, AlbumTrackTool('/content/data/chinook_sqlite.sqlite') ]
agent = CodeAgent(model=agent_model, add_base_tools=False, tools=tools)

# %%
# TODO: List of tools
for t in agent.tools.keys():
  print(t)
# Out:
# get_latlng
# get_temperature
# album_track
# final_answer

# %%
# TODO: Perform task with get_latlng and get_temperature function
result = agent.run('What is the temperature in Hougang? If you cannot find it say "NOT FOUND"', max_steps=1)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is the temperature in Hougang? If you cannot find it say "NOT FOUND"                                       │
# │                                                                                                                 │
# ╰─ OpenAIServerModel - gpt-4.1-mini ──────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # Get the latitude and longitude for Hougang
#   hougang_coords = get_latlng(city="Hougang")
#   print(hougang_coords)
# ...

# %%
#TODO: Rerun the query
band = "michael jackson"
# band = "men At work"
# band = 'james brown'
result = agent.run('List all the songs with city names and get their current temperature. If you cannot get the temperature say NA.')
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ List all the songs with city names and get their current temperature. If you cannot get the temperature say NA. │
# │                                                                                                                 │
# ╰─ OpenAIServerModel - gpt-4.1-mini ──────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   # To find city names, I will start by retrieving all song titles from the database to check for city names.
# ...
